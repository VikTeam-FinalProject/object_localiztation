# %%
# !git clone https://github.com/YangtaoWANG95/TokenCut
# %cd TokenCut
# Out:
# fatal: destination path 'TokenCut' already exists and is not an empty directory.
# /home/thekhoi/futme/RTD-ueh/object_localiztation/TokenCut/TokenCut

# %%
# !pip install torch==1.7.1 torchvision==0.8.2
# !pip install -r requirements.txt
# Out:
# ...
#   Using cached threadpoolctl-3.4.0-py3-none-any.whl.metadata (13 kB)
# ...
#   Using cached absl_py-2.1.0-py3-none-any.whl.metadata (2.3 kB)
# ...
#   Using cached Markdown-3.6-py3-none-any.whl.metadata (7.0 kB)
# ...
#   Using cached tensorboard_data_server-0.7.2-py3-none-manylinux_2_31_x86_64.whl.metadata (1.1 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 244.2/244.2 kB 698.1 kB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.2/12.2 MB 2.2 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 435.1/435.1 kB 1.1 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 1.5 MB/s eta 0:00:0000:0100:01
# Using cached absl_py-2.1.0-py3-none-any.whl (133 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 890.1 kB/s eta 0:00:0000:0100:01
# Using cached Markdown-3.6-py3-none-any.whl (105 kB)
# Using cached tensorboard_data_server-0.7.2-py3-none-manylinux_2_31_x86_64.whl (6.6 MB)
# ...

# %%
# Change this URL to any jpg image:
# !cd examples && wget -O test.jpg https://i.imgur.com/G4wpITa.jpg
# Out:
# --2024-04-13 19:56:44--  https://i.imgur.com/G4wpITa.jpg
# Resolving i.imgur.com (i.imgur.com)... 146.75.92.193
# Connecting to i.imgur.com (i.imgur.com)|146.75.92.193|:443... connected.
# HTTP request sent, awaiting response... 429 Unknown Error
# 2024-04-13 19:56:45 ERROR 429: Unknown Error.

# %%
# !python main_tokencut.py --image_path examples/VOC07_000012.jpg --visualize all
# Out:
# Since no pretrained weights have been provided, we load the reference pretrained DINO weights.
# Pretrained weights found at dino/dino_deitsmall16_pretrain/dino_deitsmall16_pretrain.pth and loaded with msg: <All keys matched successfully>
# Running TokenCut on the dataset VOC07_000012.jpg (exp: TokenCut-vit_small16_k)
#   0%|                                                     | 0/1 [00:00<?, ?it/s]Predictions saved at outputs/TokenCut-vit_small16_k/VOC07_000012_TokenCut_pred.jpg.
# Eigen attention saved at outputs/TokenCut-vit_small16_k/VOC07_000012_TokenCut_attn.jpg.
# 100%|█████████████████████████████████████████████| 1/1 [00:01<00:00,  1.84s/it]
# Time cost: 0:00:01.846000

# %%
import os
print (os.getcwd())
# Out:
# /home/thekhoi/futme/RTD-ueh/object_localiztation/TokenCut/TokenCut

# %%
from PIL import Image
display(Image.open('outputs/TokenCut-vit_small16_k/VOC07_000012_TokenCut_attn.jpg'))
display(Image.open('outputs/TokenCut-vit_small16_k/VOC07_000012_TokenCut_pred.jpg'))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x336>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x333>
